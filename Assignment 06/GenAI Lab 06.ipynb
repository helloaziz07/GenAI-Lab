# %% [markdown]
# ## Lab Assignment - 6
#
# #### Create a text-to-image generation pipeline using a pre-trained model like DALL-E.

# %%
# install required libraries
# !pip install transformers diffusers accelerate torch -q

# %%
# import libraries
import torch
from diffusers import DiffusionPipeline
import matplotlib.pyplot as plt

# %%
# load pre trained text to image model
from diffusers import StableDiffusionPipeline
import torch

pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=torch.float16
)

pipe = pipe.to("cuda")

# %%
# generating image
prompt = "a futuristic robot painting a picture, digital art"

image = pipe(prompt).images[0]

image

# %%
# saving the image
image.save("generated_image.png")
